# %%
# import the library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot  as plt
# %matplotlib inline

# %%
# data import and reading
df = pd.read_csv('/content/drive/MyDrive/miller2005_genomicMatrix',delimiter = "\t")
df.head()
# Out:
#          probe   X100B08   X101B88   X102B06   X103B41   X104B91   X105B13  \
# 0  211050_x_at -0.606098 -0.712117 -0.249024  0.473394 -0.549072 -0.309201
# 1    220399_at  0.297762  0.108554  0.529916 -0.023698 -0.240675 -0.186095
# 2  202115_s_at -0.020720 -0.329813 -0.455560  0.335867  0.091474 -0.064934
# 3    224501_at  0.019116 -0.508560  0.056202 -0.011279  0.189046  0.696562
# 4  227347_x_at  0.217003  0.750269  0.469504 -0.182406 -0.472260  0.294003
#
#     X106B55    X10B88   X110B34  ...    X85A03    X86A40    X87A79    X88A67  \
# 0  0.418973 -0.394657 -0.472516  ...  0.194257 -0.014784  0.134075 -0.199902
# 1  0.002805 -0.131806  0.113295  ...  0.158997  0.228585 -1.618250 -0.237390
# 2  0.232192 -0.024533  0.390957  ...  0.611860  0.303448  0.073593 -0.082835
# 3  0.192982 -0.319991 -0.243859  ...  0.209864  0.215092 -0.323448 -0.020308
# 4  0.147632  0.462857  0.781625  ... -0.792750  0.744523  0.156747 -0.060445
#
# ...

# %% [markdown]
# EDA

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24711 entries, 0 to 24710
# Columns: 252 entries, probe to X9B52
# dtypes: float64(251), object(1)
# memory usage: 47.5+ MB

# %%
df.shape
# Out:
# (24711, 252)

# %%
# description of data
df.describe()
# Out:
#             X100B08       X101B88       X102B06       X103B41       X104B91  \
# count  24711.000000  24711.000000  24711.000000  24711.000000  24711.000000
# mean      -0.023264     -0.024046     -0.026358     -0.028371     -0.022795
# std        0.514237      0.689058      0.612713      0.676378      0.512594
# min       -3.258706     -4.892930     -3.626814     -4.731710     -3.842147
# 25%       -0.297728     -0.370250     -0.342248     -0.375774     -0.270001
# 50%       -0.031851     -0.008989     -0.022222     -0.018033     -0.000615
# 75%        0.255407      0.344790      0.293558      0.322303      0.257871
# max        2.914430      4.929605      5.577221      6.419597      4.416023
#
#             X105B13       X106B55        X10B88       X110B34       X111B51  \
# count  24711.000000  24711.000000  24711.000000  24711.000000  24711.000000
# mean      -0.024516     -0.025312     -0.022734     -0.023526     -0.023422
# ...

# %%
# histogram
for col in x.columns:
    sns.histplot(x[col],color='g')
    plt.show()

# %%
#Label 
from sklearn import preprocessing
label_encoder = preprocessing.LabelEncoder()
# Encode labels in column 'species'.
df['probe']= label_encoder.fit_transform(df['probe'])
df['probe'].unique()
# Out:
# array([10357, 19471,  1541, ...,  2254, 14152,  7549])

# %%
x = df

# %% [markdown]
# Model

# %%
# KMeans

# %%
from sklearn.cluster import KMeans

# %%
# finding the best cluster value 
wcss =[]
for i in range(1,11):
  kmeans = KMeans(n_clusters =i , init='k-means++',random_state = 42)
  kmeans.fit(x)
  wcss.append(kmeans.inertia_)

# %%
sns.set()
number_clusters = range(1,11)
plt.plot(number_clusters,wcss)
plt.title('The Elbow Point Graph')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# fit the model with best value
kmeans = KMeans(3)
kmeans.fit(x)
y = kmeans.fit_predict(x)
y
# Out:
# array([2, 0, 1, ..., 1, 2, 1], dtype=int32)

# %%
# DBSCAN

# %%
# import 
from sklearn.cluster import DBSCAN

# %%
# fit model
dbscan = DBSCAN(eps=3,min_samples=3)
lables = dbscan.fit_predict(x)

# %%
np.unique(lables)
# Out:
# array([-1])

# %%
df = df.iloc[:,:].values

# %%
df
# Out:
# array([[ 1.03570000e+04, -6.06098460e-01, -7.12117327e-01, ...,
#         -4.55767368e-02, -2.45526540e-02,  2.70666301e-01],
#        [ 1.94710000e+04,  2.97761885e-01,  1.08554029e-01, ...,
#          2.90774880e-01,  2.48706790e-01, -2.27919449e-02],
#        [ 1.54100000e+03, -2.07199587e-02, -3.29812842e-01, ...,
#         -1.14437082e-01,  2.42832780e-01,  2.18242407e-01],
#        ...,
#        [ 2.25400000e+03, -3.73383443e-01,  4.73873165e-02, ...,
#         -3.86912703e-02, -2.86595908e-01,  2.46858164e-01],
#        [ 1.41520000e+04,  5.33709013e-01, -6.30866141e-01, ...,
#         -1.11654599e-01,  2.25007541e-01,  4.01696115e-01],
#        [ 7.54900000e+03,  9.55099733e-01,  5.50008001e-01, ...,
#          1.09326640e+00,  7.60187207e-01,  7.61980443e-02]])

# %%
# visualization
plt.scatter(df[:,0],df[:,1], s=10, c = "green")
